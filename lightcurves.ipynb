# %%
from lightkurve import search_targetpixelfile as stf
# Out:
# /opt/anaconda3/envs/tf2.18/lib/python3.11/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# /opt/anaconda3/envs/tf2.18/lib/python3.11/site-packages/lightkurve/prf/__init__.py:7: UserWarning: Warning: the tpfmodel submodule is not available without oktopus installed, which requires a current version of autograd. See #1452 for details.
#   warnings.warn(

# %%
pf = stf('KIC 8462852', quarter=16).download(quality_bitmask='hardest')

# %%
pf.plot(frame=1)
# Out:
# <Axes: title={'center': 'Target ID: 8462852, Cadence: 66714'}, xlabel='Pixel Column Number', ylabel='Pixel Row Number'>

# %%
pf = stf('KIC 8462857', quarter=16).download(quality_bitmask='hardest')
# Out:
# Could not resolve "KIC 8462857" to a sky position.
# /opt/anaconda3/envs/tf2.18/lib/python3.11/site-packages/lightkurve/search.py:415: LightkurveWarning: Cannot download from an empty search result.
#   warnings.warn(

# %%
search_result = stf('Kepler-10')  
print(search_result)
# Out:
# SearchResult containing 75 data products.
#
#  #       mission      year   author  exptime  target_name  distance
#                                         s                   arcsec
# --- ----------------- ---- --------- ------- ------------- --------
#   0 Kepler Quarter 03 2009    Kepler      60 kplr011904151      0.0
#   1 Kepler Quarter 03 2009    Kepler      60 kplr011904151      0.0
#   2 Kepler Quarter 03 2009    Kepler      60 kplr011904151      0.0
#   3 Kepler Quarter 02 2009    Kepler      60 kplr011904151      0.0
#   4 Kepler Quarter 03 2009    Kepler    1800 kplr011904151      0.0
#   5 Kepler Quarter 00 2009    Kepler    1800 kplr011904151      0.0
#   6 Kepler Quarter 01 2009    Kepler    1800 kplr011904151      0.0
#   7 Kepler Quarter 02 2009    Kepler    1800 kplr011904151      0.0
#   8 Kepler Quarter 06 2010    Kepler      60 kplr011904151      0.0
#   9 Kepler Quarter 06 2010    Kepler      60 kplr011904151      0.0
# ...

# %%
pf1 = stf('kplr011904151', quarter=6).download(quality_bitmask='hardest')
# Out:
# /opt/anaconda3/envs/tf2.18/lib/python3.11/site-packages/lightkurve/search.py:420: LightkurveWarning: Warning: 4 files available to download. Only the first file has been downloaded. Please use `download_all()` or specify additional criteria (e.g. quarter, campaign, or sector) to limit your search.
#   warnings.warn(

# %%
pf1.plot(frame=100)
# Out:
# <Axes: title={'center': 'Target ID: 11904151, Cadence: 620663'}, xlabel='Pixel Column Number', ylabel='Pixel Row Number'>
